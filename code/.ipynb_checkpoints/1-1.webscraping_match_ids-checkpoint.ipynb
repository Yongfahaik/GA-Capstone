# %% [markdown]
# # Capstone Project: Winner Winner Chickie Dinner?
# <font size="4">Winner Prediction for Fortnite</font>

# %% [markdown]
# ---
#
# ## Table of Contents
#
# ### [Overview](#Overview)
#
# ### [Problem Statement](#ProbState)
#
# ### [Part 1: Data Collection](#Part1)
# 1. [**Imports (All imported libraries are added here)**](#imports)
# 2. [**Web scraping**](#scrape)
#     2.1 [Events Archive](#events)
#     2.2 [Match IDs](#matchid)
# 3. [**Progress thus far**](#progress)
#
# ---

# %% [markdown]
# <a id='Overview'></a>
# ## Overview
#
# Electronic sports (or e-sports) is a form of competition using video games, and takes the format of organized multiplayer video game competitions held between professional players, either as an individual or as a team. The video game genres normally associated with e-sports are Multiplayer Online Battle Arena (MOBA), First-Person Shooter (FPS), Battle Royale, Real-Time Strategy (RTS), Fighting, Collectible Card Games (CCG) and Sports & Racing.
#
# Based on the reports by Newzoo (games and esports analytics group), the global revenue for esports for year 2020 reached 1 billion dollars and the global audience reached 495 million. ([Source](https://venturebeat.com/2020/02/25/newzoo-global-esports-will-top-1-billion-in-2020-with-china-as-the-top-market/)). Looking at the historical data from Esports Earnings, considering how the prize money for tournaments is over 200 million dollars for the years 2019 and 2021, and 125 million dollars in 2020 despite the COVID-19 pandemic, it comes as no surprise that there is an increasing focus on sports in the recent years. ([Source](https://www.esportsearnings.com/history)).
#
# In the case of Singapore, as the host of first Asian edition of Gamescom (The world's largest video game industry event) as well as the host for the Global Esport Games in the year 2021 last year, it is without doubt that the e-sports sector will become increasingly more important, with Singapore being the epicenter for the South-East Asia region. ([Source](https://www.straitstimes.com/business/companies-markets/singapore-sets-sights-on-becoming-world-force-in-e-sports)).

# %% [markdown]
# <a id='ProbState'></a>
# ## Problem Statement
#
# With how popular the e-sports sector is, it comes without a doubt that the most popular form of entertainment is going to be imminent, the act of guessing the winner. As such, this project will be tackling the subject of winner prediction.
#
# Looking at the various genres of video games, team sports such as MOBA, FPS and RTS tends to be more popular and easier to guess the winner since the matches are between two teams. As such, this project will be undertaking the task of predicting the winner of a match of a Battle Royale game. In this case, the focus will be on Fortnite, the current third highest prize-awarding game. ([Source](https://www.esportsearnings.com/games)).
#
# Fortnite by itself as a battle royale has various match modes that cater to the preferences of the player that are divided into the number of people in same group fighting for the winner spot. In this case, they are 'Solo' for 1v1 matches, 'Duos' for teams of 2, 'Trios' for teams of 3 and 'Squads' for teams of 4.
#
# To simplify this project, the main task of this project will be the development of a classification-based model to handle the prediction of the winner of a solo match in Fortnite. Since the act of winner prediction is usually before the beginning of the match, this task will be based off the historical player statistics.

# %% [markdown]
# <a id='Part1'></a>
# ## Part 1: Data Collection
# In this notebook, the first part of the web scraping process is conducted where we gather the `match ids` which will allow us to identify and scrape for the match statistics that we need for our data.

# %% [markdown]
# <a id='imports'></a>
# ### 1. Imports (All imported libraries are added here)

# %%
# Import libaries
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup

import selenium
from selenium import webdriver

# %% [markdown]
# <a id='scrape'></a>
# ### 2. Web scraping

# %%
# Defining base url
base_url = "https://fortnitetracker.com"

# %% [markdown]
# <a id='events'></a>
# ### 2.1 Events Archive
#
# At this point in time, we will be scraping for the data of the events archive to begin the process of gathering of the data needed for this project.

# %%
# url for events archived
url = base_url + '/events/archived/'

# %%
# requests
req = requests.get(url)
soup = BeautifulSoup(req.content, "lxml")

# Compiling dataframe of tournaments
tourneylist = soup.find_all('a', {'class': "fne-poster__child"})

tournaments = []
for i in tourneylist:
    tourney = {}
    tourney['region'] = i.find('span').text  
    tourney['href'] = i.attrs['href']
    tourney['status'] = i.find_all('span')[1].attrs['class'][1]
    tournaments.append(tourney)
tournaments_df = pd.DataFrame(tournaments)
tournaments_df
# Out:
#        region                                               href  \
# 0      Europe     /events/epicgames_S19_TriosHypeCup_Champion_EU
# 1     NA East    /events/epicgames_S19_TriosHypeCup_Champion_NAE
# 2     NA West    /events/epicgames_S19_TriosHypeCup_Champion_NAW
# 3     Oceania    /events/epicgames_S19_TriosHypeCup_Champion_OCE
# 4        Asia   /events/epicgames_S19_TriosHypeCup_Champion_ASIA
# ...       ...                                                ...
# 2011  Oceania   /events/epicgames_ShareTheLove_Placement_Duo_OCE
# 2012   Europe   /events/epicgames_ShareTheLove_Placement_Solo_EU
# 2013   Brazil   /events/epicgames_ShareTheLove_Placement_Solo_BR
# 2014     Asia  /events/epicgames_ShareTheLove_Placement_Solo_...
# 2015  Oceania  /events/epicgames_ShareTheLove_Placement_Solo_OCE
#
#                     status
# 0     fne-status--upcoming
# 1     fne-status--upcoming
# 2     fne-status--upcoming
# 3     fne-status--upcoming
# 4     fne-status--upcoming
# ...                    ...
# 2011     fne-status--ended
# 2012     fne-status--ended
# 2013     fne-status--ended
# 2014     fne-status--ended
# 2015     fne-status--ended
#
# [2016 rows x 3 columns]

# %%
# Excluding ongoing or upcoming tournaments
tournaments_df = tournaments_df[tournaments_df['status'] == 'fne-status--ended'].reset_index(drop = True)
tournaments_df
# Out:
#            region                                               href  \
# 0          Europe            /events/epicgames_S19_PlaystationCup_EU
# 1         NA East           /events/epicgames_S19_PlaystationCup_NAE
# 2         NA West           /events/epicgames_S19_PlaystationCup_NAW
# 3          Brazil            /events/epicgames_S19_PlaystationCup_BR
# 4     Middle East            /events/epicgames_S19_PlaystationCup_ME
# ...           ...                                                ...
# 1948      Oceania   /events/epicgames_ShareTheLove_Placement_Duo_OCE
# 1949       Europe   /events/epicgames_ShareTheLove_Placement_Solo_EU
# 1950       Brazil   /events/epicgames_ShareTheLove_Placement_Solo_BR
# 1951         Asia  /events/epicgames_ShareTheLove_Placement_Solo_...
# 1952      Oceania  /events/epicgames_ShareTheLove_Placement_Solo_OCE
#
#                  status
# 0     fne-status--ended
# 1     fne-status--ended
# 2     fne-status--ended
# 3     fne-status--ended
# 4     fne-status--ended
# ...                 ...
# 1948  fne-status--ended
# 1949  fne-status--ended
# 1950  fne-status--ended
# 1951  fne-status--ended
# 1952  fne-status--ended
#
# [1953 rows x 3 columns]

# %% [markdown]
# <a id='matchid'></a>
# ### 2.2 Match IDs
#
# At this point in time, since we now have the urls for each of the events, we will be scraping for the match ids that will be acting as the identification of the matches that we are going to use for analysis.

# %%
# %%time
# Scraping the match ids
driver = webdriver.Chrome()
matches = []

for i in tournaments_df.index:
    print(f'Scraping tournament index {i}')
    try:
        driver.get(base_url + tournaments_df['href'][i])
        imp_leaderboard = driver.execute_script('return imp_leaderboard')
    
        for j in imp_leaderboard['entries'][0]['sessionHistory']:
            match = {}
            match['tournament'] = imp_leaderboard['eventId']
            match['event_round'] = imp_leaderboard['eventWindowId']
            match['match_id'] = j['sessionId']
            matches.append(match)
                    
#     except AttributeError:
#         print ('Error in scraping with no value, skipping.')
#         continue
#     except KeyError:
#         print ('Error in scraping with missing keys, skipping.')
#         continue
    except Exception:
        print ('Error in scraping with missing javascript variable, skipping.')
        continue
   
driver.quit()
# Out:
# Scraping tournament index 0
# Scraping tournament index 1
# Scraping tournament index 2
# Scraping tournament index 3
# Scraping tournament index 4
# Scraping tournament index 5
# Scraping tournament index 6
# Scraping tournament index 7
# Scraping tournament index 8
# Scraping tournament index 9
# Scraping tournament index 10
# Scraping tournament index 11
# Scraping tournament index 12
# Scraping tournament index 13
# Scraping tournament index 14
# Scraping tournament index 15
# Scraping tournament index 16
# Scraping tournament index 17
# Scraping tournament index 18
# Scraping tournament index 19
# Scraping tournament index 20
# Scraping tournament index 21
# Scraping tournament index 22
# Scraping tournament index 23
# Scraping tournament index 24
# Scraping tournament index 25
# Scraping tournament index 26
# Scraping tournament index 27
# Scraping tournament index 28
# Scraping tournament index 29
# Scraping tournament index 30
# Scraping tournament index 31
# Scraping tournament index 32
# Scraping tournament index 33
# Scraping tournament index 34
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 35
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 36
# Scraping tournament index 37
# Scraping tournament index 38
# Scraping tournament index 39
# Scraping tournament index 40
# Scraping tournament index 41
# Scraping tournament index 42
# Scraping tournament index 43
# Scraping tournament index 44
# Scraping tournament index 45
# Scraping tournament index 46
# Scraping tournament index 47
# Scraping tournament index 48
# Scraping tournament index 49
# Scraping tournament index 50
# Scraping tournament index 51
# Scraping tournament index 52
# Scraping tournament index 53
# Scraping tournament index 54
# Scraping tournament index 55
# Scraping tournament index 56
# Scraping tournament index 57
# Scraping tournament index 58
# Scraping tournament index 59
# Scraping tournament index 60
# Scraping tournament index 61
# Scraping tournament index 62
# Scraping tournament index 63
# Scraping tournament index 64
# Scraping tournament index 65
# Scraping tournament index 66
# Scraping tournament index 67
# Scraping tournament index 68
# Scraping tournament index 69
# Scraping tournament index 70
# Scraping tournament index 71
# Scraping tournament index 72
# Scraping tournament index 73
# Scraping tournament index 74
# Scraping tournament index 75
# Scraping tournament index 76
# Scraping tournament index 77
# Scraping tournament index 78
# Scraping tournament index 79
# Scraping tournament index 80
# Scraping tournament index 81
# Scraping tournament index 82
# Scraping tournament index 83
# Scraping tournament index 84
# Scraping tournament index 85
# Scraping tournament index 86
# Scraping tournament index 87
# Scraping tournament index 88
# Scraping tournament index 89
# Scraping tournament index 90
# Scraping tournament index 91
# Scraping tournament index 92
# Scraping tournament index 93
# Scraping tournament index 94
# Scraping tournament index 95
# Scraping tournament index 96
# Scraping tournament index 97
# Scraping tournament index 98
# Scraping tournament index 99
# Scraping tournament index 100
# Scraping tournament index 101
# Scraping tournament index 102
# Scraping tournament index 103
# Scraping tournament index 104
# Scraping tournament index 105
# Scraping tournament index 106
# Scraping tournament index 107
# Scraping tournament index 108
# Scraping tournament index 109
# Scraping tournament index 110
# Scraping tournament index 111
# Scraping tournament index 112
# Scraping tournament index 113
# Scraping tournament index 114
# Scraping tournament index 115
# Scraping tournament index 116
# Scraping tournament index 117
# Scraping tournament index 118
# Scraping tournament index 119
# Scraping tournament index 120
# Scraping tournament index 121
# Scraping tournament index 122
# Scraping tournament index 123
# Scraping tournament index 124
# Scraping tournament index 125
# Scraping tournament index 126
# Scraping tournament index 127
# Scraping tournament index 128
# Scraping tournament index 129
# Scraping tournament index 130
# Scraping tournament index 131
# Scraping tournament index 132
# Scraping tournament index 133
# Scraping tournament index 134
# Scraping tournament index 135
# Scraping tournament index 136
# Scraping tournament index 137
# Scraping tournament index 138
# Scraping tournament index 139
# Scraping tournament index 140
# Scraping tournament index 141
# Scraping tournament index 142
# Scraping tournament index 143
# Scraping tournament index 144
# Scraping tournament index 145
# Scraping tournament index 146
# Scraping tournament index 147
# Scraping tournament index 148
# Scraping tournament index 149
# Scraping tournament index 150
# Scraping tournament index 151
# Scraping tournament index 152
# Scraping tournament index 153
# Scraping tournament index 154
# Scraping tournament index 155
# Scraping tournament index 156
# Scraping tournament index 157
# Scraping tournament index 158
# Scraping tournament index 159
# Scraping tournament index 160
# Scraping tournament index 161
# Scraping tournament index 162
# Scraping tournament index 163
# Scraping tournament index 164
# Scraping tournament index 165
# Scraping tournament index 166
# Scraping tournament index 167
# Scraping tournament index 168
# Scraping tournament index 169
# Scraping tournament index 170
# Scraping tournament index 171
# Scraping tournament index 172
# Scraping tournament index 173
# Scraping tournament index 174
# Scraping tournament index 175
# Scraping tournament index 176
# Scraping tournament index 177
# Scraping tournament index 178
# Scraping tournament index 179
# Scraping tournament index 180
# Scraping tournament index 181
# Scraping tournament index 182
# Scraping tournament index 183
# Scraping tournament index 184
# Scraping tournament index 185
# Scraping tournament index 186
# Scraping tournament index 187
# Scraping tournament index 188
# Scraping tournament index 189
# Scraping tournament index 190
# Scraping tournament index 191
# Scraping tournament index 192
# Scraping tournament index 193
# Scraping tournament index 194
# Scraping tournament index 195
# Scraping tournament index 196
# Scraping tournament index 197
# Scraping tournament index 198
# Scraping tournament index 199
# Scraping tournament index 200
# Scraping tournament index 201
# Scraping tournament index 202
# Scraping tournament index 203
# Scraping tournament index 204
# Scraping tournament index 205
# Scraping tournament index 206
# Scraping tournament index 207
# Scraping tournament index 208
# Scraping tournament index 209
# Scraping tournament index 210
# Scraping tournament index 211
# Scraping tournament index 212
# Scraping tournament index 213
# Scraping tournament index 214
# Scraping tournament index 215
# Scraping tournament index 216
# Scraping tournament index 217
# Scraping tournament index 218
# Scraping tournament index 219
# Scraping tournament index 220
# Scraping tournament index 221
# Scraping tournament index 222
# Scraping tournament index 223
# Scraping tournament index 224
# Scraping tournament index 225
# Scraping tournament index 226
# Scraping tournament index 227
# Scraping tournament index 228
# Scraping tournament index 229
# Scraping tournament index 230
# Scraping tournament index 231
# Scraping tournament index 232
# Scraping tournament index 233
# Scraping tournament index 234
# Scraping tournament index 235
# Scraping tournament index 236
# Scraping tournament index 237
# Scraping tournament index 238
# Scraping tournament index 239
# Scraping tournament index 240
# Scraping tournament index 241
# Scraping tournament index 242
# Scraping tournament index 243
# Scraping tournament index 244
# Scraping tournament index 245
# Scraping tournament index 246
# Scraping tournament index 247
# Scraping tournament index 248
# Scraping tournament index 249
# Scraping tournament index 250
# Scraping tournament index 251
# Scraping tournament index 252
# Scraping tournament index 253
# Scraping tournament index 254
# Scraping tournament index 255
# Scraping tournament index 256
# Scraping tournament index 257
# Scraping tournament index 258
# Scraping tournament index 259
# Scraping tournament index 260
# Scraping tournament index 261
# Scraping tournament index 262
# Scraping tournament index 263
# Scraping tournament index 264
# Scraping tournament index 265
# Scraping tournament index 266
# Scraping tournament index 267
# Scraping tournament index 268
# Scraping tournament index 269
# Scraping tournament index 270
# Scraping tournament index 271
# Scraping tournament index 272
# Scraping tournament index 273
# Scraping tournament index 274
# Scraping tournament index 275
# Scraping tournament index 276
# Scraping tournament index 277
# Scraping tournament index 278
# Scraping tournament index 279
# Scraping tournament index 280
# Scraping tournament index 281
# Scraping tournament index 282
# Scraping tournament index 283
# Scraping tournament index 284
# Scraping tournament index 285
# Scraping tournament index 286
# Scraping tournament index 287
# Scraping tournament index 288
# Scraping tournament index 289
# Scraping tournament index 290
# Scraping tournament index 291
# Scraping tournament index 292
# Scraping tournament index 293
# Scraping tournament index 294
# Scraping tournament index 295
# Scraping tournament index 296
# Scraping tournament index 297
# Scraping tournament index 298
# Scraping tournament index 299
# Scraping tournament index 300
# Scraping tournament index 301
# Scraping tournament index 302
# Scraping tournament index 303
# Scraping tournament index 304
# Scraping tournament index 305
# Scraping tournament index 306
# Scraping tournament index 307
# Scraping tournament index 308
# Scraping tournament index 309
# Scraping tournament index 310
# Scraping tournament index 311
# Scraping tournament index 312
# Scraping tournament index 313
# Scraping tournament index 314
# Scraping tournament index 315
# Scraping tournament index 316
# Scraping tournament index 317
# Scraping tournament index 318
# Scraping tournament index 319
# Scraping tournament index 320
# Scraping tournament index 321
# Scraping tournament index 322
# Scraping tournament index 323
# Scraping tournament index 324
# Scraping tournament index 325
# Scraping tournament index 326
# Scraping tournament index 327
# Scraping tournament index 328
# Scraping tournament index 329
# Scraping tournament index 330
# Scraping tournament index 331
# Scraping tournament index 332
# Scraping tournament index 333
# Scraping tournament index 334
# Scraping tournament index 335
# Scraping tournament index 336
# Scraping tournament index 337
# Scraping tournament index 338
# Scraping tournament index 339
# Scraping tournament index 340
# Scraping tournament index 341
# Scraping tournament index 342
# Scraping tournament index 343
# Scraping tournament index 344
# Scraping tournament index 345
# Scraping tournament index 346
# Scraping tournament index 347
# Scraping tournament index 348
# Scraping tournament index 349
# Scraping tournament index 350
# Scraping tournament index 351
# Scraping tournament index 352
# Scraping tournament index 353
# Scraping tournament index 354
# Scraping tournament index 355
# Scraping tournament index 356
# Scraping tournament index 357
# Scraping tournament index 358
# Scraping tournament index 359
# Scraping tournament index 360
# Scraping tournament index 361
# Scraping tournament index 362
# Scraping tournament index 363
# Scraping tournament index 364
# Scraping tournament index 365
# Scraping tournament index 366
# Scraping tournament index 367
# Scraping tournament index 368
# Scraping tournament index 369
# Scraping tournament index 370
# Scraping tournament index 371
# Scraping tournament index 372
# Scraping tournament index 373
# Scraping tournament index 374
# Scraping tournament index 375
# Scraping tournament index 376
# Scraping tournament index 377
# Scraping tournament index 378
# Scraping tournament index 379
# Scraping tournament index 380
# Scraping tournament index 381
# Scraping tournament index 382
# Scraping tournament index 383
# Scraping tournament index 384
# Scraping tournament index 385
# Scraping tournament index 386
# Scraping tournament index 387
# Scraping tournament index 388
# Scraping tournament index 389
# Scraping tournament index 390
# Scraping tournament index 391
# Scraping tournament index 392
# Scraping tournament index 393
# Scraping tournament index 394
# Scraping tournament index 395
# Scraping tournament index 396
# Scraping tournament index 397
# Scraping tournament index 398
# Scraping tournament index 399
# Scraping tournament index 400
# Scraping tournament index 401
# Scraping tournament index 402
# Scraping tournament index 403
# Scraping tournament index 404
# Scraping tournament index 405
# Scraping tournament index 406
# Scraping tournament index 407
# Scraping tournament index 408
# Scraping tournament index 409
# Scraping tournament index 410
# Scraping tournament index 411
# Scraping tournament index 412
# Scraping tournament index 413
# Scraping tournament index 414
# Scraping tournament index 415
# Scraping tournament index 416
# Scraping tournament index 417
# Scraping tournament index 418
# Scraping tournament index 419
# Scraping tournament index 420
# Scraping tournament index 421
# Scraping tournament index 422
# Scraping tournament index 423
# Scraping tournament index 424
# Scraping tournament index 425
# Scraping tournament index 426
# Scraping tournament index 427
# Scraping tournament index 428
# Scraping tournament index 429
# Scraping tournament index 430
# Scraping tournament index 431
# Scraping tournament index 432
# Scraping tournament index 433
# Scraping tournament index 434
# Scraping tournament index 435
# Scraping tournament index 436
# Scraping tournament index 437
# Scraping tournament index 438
# Scraping tournament index 439
# Scraping tournament index 440
# Scraping tournament index 441
# Scraping tournament index 442
# Scraping tournament index 443
# Scraping tournament index 444
# Scraping tournament index 445
# Scraping tournament index 446
# Scraping tournament index 447
# Scraping tournament index 448
# Scraping tournament index 449
# Scraping tournament index 450
# Scraping tournament index 451
# Scraping tournament index 452
# Scraping tournament index 453
# Scraping tournament index 454
# Scraping tournament index 455
# Scraping tournament index 456
# Scraping tournament index 457
# Scraping tournament index 458
# Scraping tournament index 459
# Scraping tournament index 460
# Scraping tournament index 461
# Scraping tournament index 462
# Scraping tournament index 463
# Scraping tournament index 464
# Scraping tournament index 465
# Scraping tournament index 466
# Scraping tournament index 467
# Scraping tournament index 468
# Scraping tournament index 469
# Scraping tournament index 470
# Scraping tournament index 471
# Scraping tournament index 472
# Scraping tournament index 473
# Scraping tournament index 474
# Scraping tournament index 475
# Scraping tournament index 476
# Scraping tournament index 477
# Scraping tournament index 478
# Scraping tournament index 479
# Scraping tournament index 480
# Scraping tournament index 481
# Scraping tournament index 482
# Scraping tournament index 483
# Scraping tournament index 484
# Scraping tournament index 485
# Scraping tournament index 486
# Scraping tournament index 487
# Scraping tournament index 488
# Scraping tournament index 489
# Scraping tournament index 490
# Scraping tournament index 491
# Scraping tournament index 492
# Scraping tournament index 493
# Scraping tournament index 494
# Scraping tournament index 495
# Scraping tournament index 496
# Scraping tournament index 497
# Scraping tournament index 498
# Scraping tournament index 499
# Scraping tournament index 500
# Scraping tournament index 501
# Scraping tournament index 502
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 503
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 504
# Scraping tournament index 505
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 506
# Scraping tournament index 507
# Scraping tournament index 508
# Scraping tournament index 509
# Scraping tournament index 510
# Scraping tournament index 511
# Scraping tournament index 512
# Scraping tournament index 513
# Scraping tournament index 514
# Scraping tournament index 515
# Scraping tournament index 516
# Scraping tournament index 517
# Scraping tournament index 518
# Scraping tournament index 519
# Scraping tournament index 520
# Scraping tournament index 521
# Scraping tournament index 522
# Scraping tournament index 523
# Scraping tournament index 524
# Scraping tournament index 525
# Scraping tournament index 526
# Scraping tournament index 527
# Scraping tournament index 528
# Scraping tournament index 529
# Scraping tournament index 530
# Scraping tournament index 531
# Scraping tournament index 532
# Scraping tournament index 533
# Scraping tournament index 534
# Scraping tournament index 535
# Scraping tournament index 536
# Scraping tournament index 537
# Scraping tournament index 538
# Scraping tournament index 539
# Scraping tournament index 540
# Scraping tournament index 541
# Scraping tournament index 542
# Scraping tournament index 543
# Scraping tournament index 544
# Scraping tournament index 545
# Scraping tournament index 546
# Scraping tournament index 547
# Scraping tournament index 548
# Scraping tournament index 549
# Scraping tournament index 550
# Scraping tournament index 551
# Scraping tournament index 552
# Scraping tournament index 553
# Scraping tournament index 554
# Scraping tournament index 555
# Scraping tournament index 556
# Scraping tournament index 557
# Scraping tournament index 558
# Scraping tournament index 559
# Scraping tournament index 560
# Scraping tournament index 561
# Scraping tournament index 562
# Scraping tournament index 563
# Scraping tournament index 564
# Scraping tournament index 565
# Scraping tournament index 566
# Scraping tournament index 567
# Scraping tournament index 568
# Scraping tournament index 569
# Scraping tournament index 570
# Scraping tournament index 571
# Scraping tournament index 572
# Scraping tournament index 573
# Scraping tournament index 574
# Scraping tournament index 575
# Scraping tournament index 576
# Scraping tournament index 577
# Scraping tournament index 578
# Scraping tournament index 579
# Scraping tournament index 580
# Scraping tournament index 581
# Scraping tournament index 582
# Scraping tournament index 583
# Scraping tournament index 584
# Scraping tournament index 585
# Scraping tournament index 586
# Scraping tournament index 587
# Scraping tournament index 588
# Scraping tournament index 589
# Scraping tournament index 590
# Scraping tournament index 591
# Scraping tournament index 592
# Scraping tournament index 593
# Scraping tournament index 594
# Scraping tournament index 595
# Scraping tournament index 596
# Scraping tournament index 597
# Scraping tournament index 598
# Scraping tournament index 599
# Scraping tournament index 600
# Scraping tournament index 601
# Scraping tournament index 602
# Scraping tournament index 603
# Scraping tournament index 604
# Scraping tournament index 605
# Scraping tournament index 606
# Scraping tournament index 607
# Scraping tournament index 608
# Scraping tournament index 609
# Scraping tournament index 610
# Scraping tournament index 611
# Scraping tournament index 612
# Scraping tournament index 613
# Scraping tournament index 614
# Scraping tournament index 615
# Scraping tournament index 616
# Scraping tournament index 617
# Scraping tournament index 618
# Scraping tournament index 619
# Scraping tournament index 620
# Scraping tournament index 621
# Scraping tournament index 622
# Scraping tournament index 623
# Scraping tournament index 624
# Scraping tournament index 625
# Scraping tournament index 626
# Scraping tournament index 627
# Scraping tournament index 628
# Scraping tournament index 629
# Scraping tournament index 630
# Scraping tournament index 631
# Scraping tournament index 632
# Scraping tournament index 633
# Scraping tournament index 634
# Scraping tournament index 635
# Scraping tournament index 636
# Scraping tournament index 637
# Scraping tournament index 638
# Scraping tournament index 639
# Scraping tournament index 640
# Scraping tournament index 641
# Scraping tournament index 642
# Scraping tournament index 643
# Scraping tournament index 644
# Scraping tournament index 645
# Scraping tournament index 646
# Scraping tournament index 647
# Scraping tournament index 648
# Scraping tournament index 649
# Scraping tournament index 650
# Scraping tournament index 651
# Scraping tournament index 652
# Scraping tournament index 653
# Scraping tournament index 654
# Scraping tournament index 655
# Scraping tournament index 656
# Scraping tournament index 657
# Scraping tournament index 658
# Scraping tournament index 659
# Scraping tournament index 660
# Scraping tournament index 661
# Scraping tournament index 662
# Scraping tournament index 663
# Scraping tournament index 664
# Scraping tournament index 665
# Scraping tournament index 666
# Scraping tournament index 667
# Scraping tournament index 668
# Scraping tournament index 669
# Scraping tournament index 670
# Scraping tournament index 671
# Scraping tournament index 672
# Scraping tournament index 673
# Scraping tournament index 674
# Scraping tournament index 675
# Scraping tournament index 676
# Scraping tournament index 677
# Scraping tournament index 678
# Scraping tournament index 679
# Scraping tournament index 680
# Scraping tournament index 681
# Scraping tournament index 682
# Scraping tournament index 683
# Scraping tournament index 684
# Scraping tournament index 685
# Scraping tournament index 686
# Scraping tournament index 687
# Scraping tournament index 688
# Scraping tournament index 689
# Scraping tournament index 690
# Scraping tournament index 691
# Scraping tournament index 692
# Scraping tournament index 693
# Scraping tournament index 694
# Scraping tournament index 695
# Scraping tournament index 696
# Scraping tournament index 697
# Scraping tournament index 698
# Scraping tournament index 699
# Scraping tournament index 700
# Scraping tournament index 701
# Scraping tournament index 702
# Scraping tournament index 703
# Scraping tournament index 704
# Scraping tournament index 705
# Scraping tournament index 706
# Scraping tournament index 707
# Scraping tournament index 708
# Scraping tournament index 709
# Scraping tournament index 710
# Scraping tournament index 711
# Scraping tournament index 712
# Scraping tournament index 713
# Scraping tournament index 714
# Scraping tournament index 715
# Scraping tournament index 716
# Scraping tournament index 717
# Scraping tournament index 718
# Scraping tournament index 719
# Scraping tournament index 720
# Scraping tournament index 721
# Scraping tournament index 722
# Scraping tournament index 723
# Scraping tournament index 724
# Scraping tournament index 725
# Scraping tournament index 726
# Scraping tournament index 727
# Scraping tournament index 728
# Scraping tournament index 729
# Scraping tournament index 730
# Scraping tournament index 731
# Scraping tournament index 732
# Scraping tournament index 733
# Scraping tournament index 734
# Scraping tournament index 735
# Scraping tournament index 736
# Scraping tournament index 737
# Scraping tournament index 738
# Scraping tournament index 739
# Scraping tournament index 740
# Scraping tournament index 741
# Scraping tournament index 742
# Scraping tournament index 743
# Scraping tournament index 744
# Scraping tournament index 745
# Scraping tournament index 746
# Scraping tournament index 747
# Scraping tournament index 748
# Scraping tournament index 749
# Scraping tournament index 750
# Scraping tournament index 751
# Scraping tournament index 752
# Scraping tournament index 753
# Scraping tournament index 754
# Scraping tournament index 755
# Scraping tournament index 756
# Scraping tournament index 757
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 758
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 759
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 760
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 761
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 762
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 763
# Scraping tournament index 764
# Scraping tournament index 765
# Scraping tournament index 766
# Scraping tournament index 767
# Scraping tournament index 768
# Scraping tournament index 769
# Scraping tournament index 770
# Scraping tournament index 771
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 772
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 773
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 774
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 775
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 776
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 777
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 778
# Scraping tournament index 779
# Scraping tournament index 780
# Scraping tournament index 781
# Scraping tournament index 782
# Scraping tournament index 783
# Scraping tournament index 784
# Scraping tournament index 785
# Scraping tournament index 786
# Scraping tournament index 787
# Scraping tournament index 788
# Scraping tournament index 789
# Scraping tournament index 790
# Scraping tournament index 791
# Scraping tournament index 792
# Scraping tournament index 793
# Scraping tournament index 794
# Scraping tournament index 795
# Scraping tournament index 796
# Scraping tournament index 797
# Scraping tournament index 798
# Scraping tournament index 799
# Scraping tournament index 800
# Scraping tournament index 801
# Scraping tournament index 802
# Scraping tournament index 803
# Scraping tournament index 804
# Scraping tournament index 805
# Scraping tournament index 806
# Scraping tournament index 807
# Scraping tournament index 808
# Scraping tournament index 809
# Scraping tournament index 810
# Scraping tournament index 811
# Scraping tournament index 812
# Scraping tournament index 813
# Scraping tournament index 814
# Scraping tournament index 815
# Scraping tournament index 816
# Scraping tournament index 817
# Scraping tournament index 818
# Scraping tournament index 819
# Scraping tournament index 820
# Scraping tournament index 821
# Scraping tournament index 822
# Scraping tournament index 823
# Scraping tournament index 824
# Scraping tournament index 825
# Scraping tournament index 826
# Scraping tournament index 827
# Scraping tournament index 828
# Scraping tournament index 829
# Scraping tournament index 830
# Scraping tournament index 831
# Scraping tournament index 832
# Scraping tournament index 833
# Scraping tournament index 834
# Scraping tournament index 835
# Scraping tournament index 836
# Scraping tournament index 837
# Scraping tournament index 838
# Scraping tournament index 839
# Scraping tournament index 840
# Scraping tournament index 841
# Scraping tournament index 842
# Scraping tournament index 843
# Scraping tournament index 844
# Scraping tournament index 845
# Scraping tournament index 846
# Scraping tournament index 847
# Scraping tournament index 848
# Scraping tournament index 849
# Scraping tournament index 850
# Scraping tournament index 851
# Scraping tournament index 852
# Scraping tournament index 853
# Scraping tournament index 854
# Scraping tournament index 855
# Scraping tournament index 856
# Scraping tournament index 857
# Scraping tournament index 858
# Scraping tournament index 859
# Scraping tournament index 860
# Scraping tournament index 861
# Scraping tournament index 862
# Scraping tournament index 863
# Scraping tournament index 864
# Scraping tournament index 865
# Scraping tournament index 866
# Scraping tournament index 867
# Scraping tournament index 868
# Scraping tournament index 869
# Scraping tournament index 870
# Scraping tournament index 871
# Scraping tournament index 872
# Scraping tournament index 873
# Scraping tournament index 874
# Scraping tournament index 875
# Scraping tournament index 876
# Scraping tournament index 877
# Scraping tournament index 878
# Scraping tournament index 879
# Scraping tournament index 880
# Scraping tournament index 881
# Scraping tournament index 882
# Scraping tournament index 883
# Scraping tournament index 884
# Scraping tournament index 885
# Scraping tournament index 886
# Scraping tournament index 887
# Scraping tournament index 888
# Scraping tournament index 889
# Scraping tournament index 890
# Scraping tournament index 891
# Scraping tournament index 892
# Scraping tournament index 893
# Scraping tournament index 894
# Scraping tournament index 895
# Scraping tournament index 896
# Scraping tournament index 897
# Scraping tournament index 898
# Scraping tournament index 899
# Scraping tournament index 900
# Scraping tournament index 901
# Scraping tournament index 902
# Scraping tournament index 903
# Scraping tournament index 904
# Scraping tournament index 905
# Scraping tournament index 906
# Scraping tournament index 907
# Scraping tournament index 908
# Scraping tournament index 909
# Scraping tournament index 910
# Scraping tournament index 911
# Scraping tournament index 912
# Scraping tournament index 913
# Scraping tournament index 914
# Scraping tournament index 915
# Scraping tournament index 916
# Scraping tournament index 917
# Scraping tournament index 918
# Scraping tournament index 919
# Scraping tournament index 920
# Scraping tournament index 921
# Scraping tournament index 922
# Scraping tournament index 923
# Scraping tournament index 924
# Scraping tournament index 925
# Scraping tournament index 926
# Scraping tournament index 927
# Scraping tournament index 928
# Scraping tournament index 929
# Scraping tournament index 930
# Scraping tournament index 931
# Scraping tournament index 932
# Scraping tournament index 933
# Scraping tournament index 934
# Scraping tournament index 935
# Scraping tournament index 936
# Scraping tournament index 937
# Scraping tournament index 938
# Scraping tournament index 939
# Scraping tournament index 940
# Scraping tournament index 941
# Scraping tournament index 942
# Scraping tournament index 943
# Scraping tournament index 944
# Scraping tournament index 945
# Scraping tournament index 946
# Scraping tournament index 947
# Scraping tournament index 948
# Scraping tournament index 949
# Scraping tournament index 950
# Scraping tournament index 951
# Scraping tournament index 952
# Scraping tournament index 953
# Scraping tournament index 954
# Scraping tournament index 955
# Scraping tournament index 956
# Scraping tournament index 957
# Scraping tournament index 958
# Scraping tournament index 959
# Scraping tournament index 960
# Scraping tournament index 961
# Scraping tournament index 962
# Scraping tournament index 963
# Scraping tournament index 964
# Scraping tournament index 965
# Scraping tournament index 966
# Scraping tournament index 967
# Scraping tournament index 968
# Scraping tournament index 969
# Scraping tournament index 970
# Scraping tournament index 971
# Scraping tournament index 972
# Scraping tournament index 973
# Scraping tournament index 974
# Scraping tournament index 975
# Scraping tournament index 976
# Scraping tournament index 977
# Scraping tournament index 978
# Scraping tournament index 979
# Scraping tournament index 980
# Scraping tournament index 981
# Scraping tournament index 982
# Scraping tournament index 983
# Scraping tournament index 984
# Scraping tournament index 985
# Scraping tournament index 986
# Scraping tournament index 987
# Scraping tournament index 988
# Scraping tournament index 989
# Scraping tournament index 990
# Scraping tournament index 991
# Scraping tournament index 992
# Scraping tournament index 993
# Scraping tournament index 994
# Scraping tournament index 995
# Scraping tournament index 996
# Scraping tournament index 997
# Scraping tournament index 998
# Scraping tournament index 999
# Scraping tournament index 1000
# Scraping tournament index 1001
# Scraping tournament index 1002
# Scraping tournament index 1003
# Scraping tournament index 1004
# Scraping tournament index 1005
# Scraping tournament index 1006
# Scraping tournament index 1007
# Scraping tournament index 1008
# Scraping tournament index 1009
# Scraping tournament index 1010
# Scraping tournament index 1011
# Scraping tournament index 1012
# Scraping tournament index 1013
# Scraping tournament index 1014
# Scraping tournament index 1015
# Scraping tournament index 1016
# Scraping tournament index 1017
# Scraping tournament index 1018
# Scraping tournament index 1019
# Scraping tournament index 1020
# Scraping tournament index 1021
# Scraping tournament index 1022
# Scraping tournament index 1023
# Scraping tournament index 1024
# Scraping tournament index 1025
# Scraping tournament index 1026
# Scraping tournament index 1027
# Scraping tournament index 1028
# Scraping tournament index 1029
# Scraping tournament index 1030
# Scraping tournament index 1031
# Scraping tournament index 1032
# Scraping tournament index 1033
# Scraping tournament index 1034
# Scraping tournament index 1035
# Scraping tournament index 1036
# Scraping tournament index 1037
# Scraping tournament index 1038
# Scraping tournament index 1039
# Scraping tournament index 1040
# Scraping tournament index 1041
# Scraping tournament index 1042
# Scraping tournament index 1043
# Scraping tournament index 1044
# Scraping tournament index 1045
# Scraping tournament index 1046
# Scraping tournament index 1047
# Scraping tournament index 1048
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1049
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1050
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1051
# Scraping tournament index 1052
# Scraping tournament index 1053
# Scraping tournament index 1054
# Scraping tournament index 1055
# Scraping tournament index 1056
# Scraping tournament index 1057
# Scraping tournament index 1058
# Scraping tournament index 1059
# Scraping tournament index 1060
# Scraping tournament index 1061
# Scraping tournament index 1062
# Scraping tournament index 1063
# Scraping tournament index 1064
# Scraping tournament index 1065
# Scraping tournament index 1066
# Scraping tournament index 1067
# Scraping tournament index 1068
# Scraping tournament index 1069
# Scraping tournament index 1070
# Scraping tournament index 1071
# Scraping tournament index 1072
# Scraping tournament index 1073
# Scraping tournament index 1074
# Scraping tournament index 1075
# Scraping tournament index 1076
# Scraping tournament index 1077
# Scraping tournament index 1078
# Scraping tournament index 1079
# Scraping tournament index 1080
# Scraping tournament index 1081
# Scraping tournament index 1082
# Scraping tournament index 1083
# Scraping tournament index 1084
# Scraping tournament index 1085
# Scraping tournament index 1086
# Scraping tournament index 1087
# Scraping tournament index 1088
# Scraping tournament index 1089
# Scraping tournament index 1090
# Scraping tournament index 1091
# Scraping tournament index 1092
# Scraping tournament index 1093
# Scraping tournament index 1094
# Scraping tournament index 1095
# Scraping tournament index 1096
# Scraping tournament index 1097
# Scraping tournament index 1098
# Scraping tournament index 1099
# Scraping tournament index 1100
# Scraping tournament index 1101
# Scraping tournament index 1102
# Scraping tournament index 1103
# Scraping tournament index 1104
# Scraping tournament index 1105
# Scraping tournament index 1106
# Scraping tournament index 1107
# Scraping tournament index 1108
# Scraping tournament index 1109
# Scraping tournament index 1110
# Scraping tournament index 1111
# Scraping tournament index 1112
# Scraping tournament index 1113
# Scraping tournament index 1114
# Scraping tournament index 1115
# Scraping tournament index 1116
# Scraping tournament index 1117
# Scraping tournament index 1118
# Scraping tournament index 1119
# Scraping tournament index 1120
# Scraping tournament index 1121
# Scraping tournament index 1122
# Scraping tournament index 1123
# Scraping tournament index 1124
# Scraping tournament index 1125
# Scraping tournament index 1126
# Scraping tournament index 1127
# Scraping tournament index 1128
# Scraping tournament index 1129
# Scraping tournament index 1130
# Scraping tournament index 1131
# Scraping tournament index 1132
# Scraping tournament index 1133
# Scraping tournament index 1134
# Scraping tournament index 1135
# Scraping tournament index 1136
# Scraping tournament index 1137
# Scraping tournament index 1138
# Scraping tournament index 1139
# Scraping tournament index 1140
# Scraping tournament index 1141
# Scraping tournament index 1142
# Scraping tournament index 1143
# Scraping tournament index 1144
# Scraping tournament index 1145
# Scraping tournament index 1146
# Scraping tournament index 1147
# Scraping tournament index 1148
# Scraping tournament index 1149
# Scraping tournament index 1150
# Scraping tournament index 1151
# Scraping tournament index 1152
# Scraping tournament index 1153
# Scraping tournament index 1154
# Scraping tournament index 1155
# Scraping tournament index 1156
# Scraping tournament index 1157
# Scraping tournament index 1158
# Scraping tournament index 1159
# Scraping tournament index 1160
# Scraping tournament index 1161
# Scraping tournament index 1162
# Scraping tournament index 1163
# Scraping tournament index 1164
# Scraping tournament index 1165
# Scraping tournament index 1166
# Scraping tournament index 1167
# Scraping tournament index 1168
# Scraping tournament index 1169
# Scraping tournament index 1170
# Scraping tournament index 1171
# Scraping tournament index 1172
# Scraping tournament index 1173
# Scraping tournament index 1174
# Scraping tournament index 1175
# Scraping tournament index 1176
# Scraping tournament index 1177
# Scraping tournament index 1178
# Scraping tournament index 1179
# Scraping tournament index 1180
# Scraping tournament index 1181
# Scraping tournament index 1182
# Scraping tournament index 1183
# Scraping tournament index 1184
# Scraping tournament index 1185
# Scraping tournament index 1186
# Scraping tournament index 1187
# Scraping tournament index 1188
# Scraping tournament index 1189
# Scraping tournament index 1190
# Scraping tournament index 1191
# Scraping tournament index 1192
# Scraping tournament index 1193
# Scraping tournament index 1194
# Scraping tournament index 1195
# Scraping tournament index 1196
# Scraping tournament index 1197
# Scraping tournament index 1198
# Scraping tournament index 1199
# Scraping tournament index 1200
# Scraping tournament index 1201
# Scraping tournament index 1202
# Scraping tournament index 1203
# Scraping tournament index 1204
# Scraping tournament index 1205
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1206
# Scraping tournament index 1207
# Scraping tournament index 1208
# Scraping tournament index 1209
# Scraping tournament index 1210
# Scraping tournament index 1211
# Scraping tournament index 1212
# Scraping tournament index 1213
# Scraping tournament index 1214
# Scraping tournament index 1215
# Scraping tournament index 1216
# Scraping tournament index 1217
# Scraping tournament index 1218
# Scraping tournament index 1219
# Scraping tournament index 1220
# Scraping tournament index 1221
# Scraping tournament index 1222
# Scraping tournament index 1223
# Scraping tournament index 1224
# Scraping tournament index 1225
# Scraping tournament index 1226
# Scraping tournament index 1227
# Scraping tournament index 1228
# Scraping tournament index 1229
# Scraping tournament index 1230
# Scraping tournament index 1231
# Scraping tournament index 1232
# Scraping tournament index 1233
# Scraping tournament index 1234
# Scraping tournament index 1235
# Scraping tournament index 1236
# Scraping tournament index 1237
# Scraping tournament index 1238
# Scraping tournament index 1239
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1240
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1241
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1242
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1243
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1244
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1245
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1246
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1247
# Scraping tournament index 1248
# Scraping tournament index 1249
# Scraping tournament index 1250
# Scraping tournament index 1251
# Scraping tournament index 1252
# Scraping tournament index 1253
# Scraping tournament index 1254
# Scraping tournament index 1255
# Scraping tournament index 1256
# Scraping tournament index 1257
# Scraping tournament index 1258
# Scraping tournament index 1259
# Scraping tournament index 1260
# Scraping tournament index 1261
# Scraping tournament index 1262
# Scraping tournament index 1263
# Scraping tournament index 1264
# Scraping tournament index 1265
# Scraping tournament index 1266
# Scraping tournament index 1267
# Scraping tournament index 1268
# Scraping tournament index 1269
# Scraping tournament index 1270
# Scraping tournament index 1271
# Scraping tournament index 1272
# Scraping tournament index 1273
# Scraping tournament index 1274
# Scraping tournament index 1275
# Scraping tournament index 1276
# Scraping tournament index 1277
# Scraping tournament index 1278
# Scraping tournament index 1279
# Scraping tournament index 1280
# Scraping tournament index 1281
# Scraping tournament index 1282
# Scraping tournament index 1283
# Scraping tournament index 1284
# Scraping tournament index 1285
# Scraping tournament index 1286
# Scraping tournament index 1287
# Scraping tournament index 1288
# Scraping tournament index 1289
# Scraping tournament index 1290
# Scraping tournament index 1291
# Scraping tournament index 1292
# Scraping tournament index 1293
# Scraping tournament index 1294
# Scraping tournament index 1295
# Scraping tournament index 1296
# Scraping tournament index 1297
# Scraping tournament index 1298
# Scraping tournament index 1299
# Scraping tournament index 1300
# Scraping tournament index 1301
# Scraping tournament index 1302
# Scraping tournament index 1303
# Scraping tournament index 1304
# Scraping tournament index 1305
# Scraping tournament index 1306
# Scraping tournament index 1307
# Scraping tournament index 1308
# Scraping tournament index 1309
# Scraping tournament index 1310
# Scraping tournament index 1311
# Scraping tournament index 1312
# Scraping tournament index 1313
# Scraping tournament index 1314
# Scraping tournament index 1315
# Scraping tournament index 1316
# Scraping tournament index 1317
# Scraping tournament index 1318
# Scraping tournament index 1319
# Scraping tournament index 1320
# Scraping tournament index 1321
# Scraping tournament index 1322
# Scraping tournament index 1323
# Scraping tournament index 1324
# Scraping tournament index 1325
# Scraping tournament index 1326
# Scraping tournament index 1327
# Scraping tournament index 1328
# Scraping tournament index 1329
# Scraping tournament index 1330
# Scraping tournament index 1331
# Scraping tournament index 1332
# Scraping tournament index 1333
# Scraping tournament index 1334
# Scraping tournament index 1335
# Scraping tournament index 1336
# Scraping tournament index 1337
# Scraping tournament index 1338
# Scraping tournament index 1339
# Scraping tournament index 1340
# Scraping tournament index 1341
# Scraping tournament index 1342
# Scraping tournament index 1343
# Scraping tournament index 1344
# Scraping tournament index 1345
# Scraping tournament index 1346
# Scraping tournament index 1347
# Scraping tournament index 1348
# Scraping tournament index 1349
# Scraping tournament index 1350
# Scraping tournament index 1351
# Scraping tournament index 1352
# Scraping tournament index 1353
# Scraping tournament index 1354
# Scraping tournament index 1355
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1356
# Scraping tournament index 1357
# Scraping tournament index 1358
# Scraping tournament index 1359
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1360
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1361
# Scraping tournament index 1362
# Scraping tournament index 1363
# Scraping tournament index 1364
# Scraping tournament index 1365
# Scraping tournament index 1366
# Scraping tournament index 1367
# Scraping tournament index 1368
# Scraping tournament index 1369
# Scraping tournament index 1370
# Scraping tournament index 1371
# Scraping tournament index 1372
# Scraping tournament index 1373
# Scraping tournament index 1374
# Scraping tournament index 1375
# Scraping tournament index 1376
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1377
# Scraping tournament index 1378
# Scraping tournament index 1379
# Scraping tournament index 1380
# Scraping tournament index 1381
# Scraping tournament index 1382
# Scraping tournament index 1383
# Scraping tournament index 1384
# Scraping tournament index 1385
# Scraping tournament index 1386
# Scraping tournament index 1387
# Scraping tournament index 1388
# Scraping tournament index 1389
# Scraping tournament index 1390
# Scraping tournament index 1391
# Scraping tournament index 1392
# Scraping tournament index 1393
# Scraping tournament index 1394
# Scraping tournament index 1395
# Scraping tournament index 1396
# Scraping tournament index 1397
# Scraping tournament index 1398
# Scraping tournament index 1399
# Scraping tournament index 1400
# Scraping tournament index 1401
# Scraping tournament index 1402
# Scraping tournament index 1403
# Scraping tournament index 1404
# Scraping tournament index 1405
# Scraping tournament index 1406
# Scraping tournament index 1407
# Scraping tournament index 1408
# Scraping tournament index 1409
# Scraping tournament index 1410
# Scraping tournament index 1411
# Scraping tournament index 1412
# Scraping tournament index 1413
# Scraping tournament index 1414
# Scraping tournament index 1415
# Scraping tournament index 1416
# Scraping tournament index 1417
# Scraping tournament index 1418
# Scraping tournament index 1419
# Scraping tournament index 1420
# Scraping tournament index 1421
# Scraping tournament index 1422
# Scraping tournament index 1423
# Scraping tournament index 1424
# Scraping tournament index 1425
# Scraping tournament index 1426
# Scraping tournament index 1427
# Scraping tournament index 1428
# Scraping tournament index 1429
# Scraping tournament index 1430
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1431
# Scraping tournament index 1432
# Scraping tournament index 1433
# Scraping tournament index 1434
# Scraping tournament index 1435
# Scraping tournament index 1436
# Scraping tournament index 1437
# Scraping tournament index 1438
# Scraping tournament index 1439
# Scraping tournament index 1440
# Scraping tournament index 1441
# Scraping tournament index 1442
# Scraping tournament index 1443
# Scraping tournament index 1444
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1445
# Scraping tournament index 1446
# Scraping tournament index 1447
# Scraping tournament index 1448
# Scraping tournament index 1449
# Scraping tournament index 1450
# Scraping tournament index 1451
# Scraping tournament index 1452
# Scraping tournament index 1453
# Scraping tournament index 1454
# Scraping tournament index 1455
# Scraping tournament index 1456
# Scraping tournament index 1457
# Scraping tournament index 1458
# Scraping tournament index 1459
# Scraping tournament index 1460
# Scraping tournament index 1461
# Scraping tournament index 1462
# Scraping tournament index 1463
# Scraping tournament index 1464
# Scraping tournament index 1465
# Scraping tournament index 1466
# Scraping tournament index 1467
# Scraping tournament index 1468
# Scraping tournament index 1469
# Scraping tournament index 1470
# Scraping tournament index 1471
# Scraping tournament index 1472
# Scraping tournament index 1473
# Scraping tournament index 1474
# Scraping tournament index 1475
# Scraping tournament index 1476
# Scraping tournament index 1477
# Scraping tournament index 1478
# Scraping tournament index 1479
# Scraping tournament index 1480
# Scraping tournament index 1481
# Scraping tournament index 1482
# Scraping tournament index 1483
# Scraping tournament index 1484
# Scraping tournament index 1485
# Scraping tournament index 1486
# Scraping tournament index 1487
# Scraping tournament index 1488
# Scraping tournament index 1489
# Scraping tournament index 1490
# Scraping tournament index 1491
# Scraping tournament index 1492
# Scraping tournament index 1493
# Scraping tournament index 1494
# Scraping tournament index 1495
# Scraping tournament index 1496
# Scraping tournament index 1497
# Scraping tournament index 1498
# Scraping tournament index 1499
# Scraping tournament index 1500
# Scraping tournament index 1501
# Scraping tournament index 1502
# Scraping tournament index 1503
# Scraping tournament index 1504
# Scraping tournament index 1505
# Scraping tournament index 1506
# Scraping tournament index 1507
# Scraping tournament index 1508
# Scraping tournament index 1509
# Scraping tournament index 1510
# Scraping tournament index 1511
# Scraping tournament index 1512
# Scraping tournament index 1513
# Scraping tournament index 1514
# Scraping tournament index 1515
# Scraping tournament index 1516
# Scraping tournament index 1517
# Scraping tournament index 1518
# Scraping tournament index 1519
# Scraping tournament index 1520
# Scraping tournament index 1521
# Scraping tournament index 1522
# Scraping tournament index 1523
# Scraping tournament index 1524
# Scraping tournament index 1525
# Scraping tournament index 1526
# Scraping tournament index 1527
# Scraping tournament index 1528
# Scraping tournament index 1529
# Scraping tournament index 1530
# Scraping tournament index 1531
# Scraping tournament index 1532
# Scraping tournament index 1533
# Scraping tournament index 1534
# Scraping tournament index 1535
# Scraping tournament index 1536
# Scraping tournament index 1537
# Scraping tournament index 1538
# Scraping tournament index 1539
# Scraping tournament index 1540
# Scraping tournament index 1541
# Scraping tournament index 1542
# Scraping tournament index 1543
# Scraping tournament index 1544
# Scraping tournament index 1545
# Scraping tournament index 1546
# Scraping tournament index 1547
# Scraping tournament index 1548
# Scraping tournament index 1549
# Scraping tournament index 1550
# Scraping tournament index 1551
# Scraping tournament index 1552
# Scraping tournament index 1553
# Scraping tournament index 1554
# Scraping tournament index 1555
# Scraping tournament index 1556
# Scraping tournament index 1557
# Scraping tournament index 1558
# Scraping tournament index 1559
# Scraping tournament index 1560
# Scraping tournament index 1561
# Scraping tournament index 1562
# Scraping tournament index 1563
# Scraping tournament index 1564
# Scraping tournament index 1565
# Scraping tournament index 1566
# Scraping tournament index 1567
# Scraping tournament index 1568
# Scraping tournament index 1569
# Scraping tournament index 1570
# Scraping tournament index 1571
# Scraping tournament index 1572
# Scraping tournament index 1573
# Scraping tournament index 1574
# Scraping tournament index 1575
# Scraping tournament index 1576
# Scraping tournament index 1577
# Scraping tournament index 1578
# Scraping tournament index 1579
# Scraping tournament index 1580
# Scraping tournament index 1581
# Scraping tournament index 1582
# Scraping tournament index 1583
# Scraping tournament index 1584
# Scraping tournament index 1585
# Scraping tournament index 1586
# Scraping tournament index 1587
# Scraping tournament index 1588
# Scraping tournament index 1589
# Scraping tournament index 1590
# Scraping tournament index 1591
# Scraping tournament index 1592
# Scraping tournament index 1593
# Scraping tournament index 1594
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1595
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1596
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1597
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1598
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1599
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1600
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1601
# Scraping tournament index 1602
# Scraping tournament index 1603
# Scraping tournament index 1604
# Scraping tournament index 1605
# Scraping tournament index 1606
# Scraping tournament index 1607
# Scraping tournament index 1608
# Scraping tournament index 1609
# Scraping tournament index 1610
# Scraping tournament index 1611
# Scraping tournament index 1612
# Scraping tournament index 1613
# Scraping tournament index 1614
# Scraping tournament index 1615
# Scraping tournament index 1616
# Scraping tournament index 1617
# Scraping tournament index 1618
# Scraping tournament index 1619
# Scraping tournament index 1620
# Scraping tournament index 1621
# Scraping tournament index 1622
# Scraping tournament index 1623
# Scraping tournament index 1624
# Scraping tournament index 1625
# Scraping tournament index 1626
# Scraping tournament index 1627
# Scraping tournament index 1628
# Scraping tournament index 1629
# Scraping tournament index 1630
# Scraping tournament index 1631
# Scraping tournament index 1632
# Scraping tournament index 1633
# Scraping tournament index 1634
# Scraping tournament index 1635
# Scraping tournament index 1636
# Scraping tournament index 1637
# Scraping tournament index 1638
# Scraping tournament index 1639
# Scraping tournament index 1640
# Scraping tournament index 1641
# Scraping tournament index 1642
# Scraping tournament index 1643
# Scraping tournament index 1644
# Scraping tournament index 1645
# Scraping tournament index 1646
# Scraping tournament index 1647
# Scraping tournament index 1648
# Scraping tournament index 1649
# Scraping tournament index 1650
# Scraping tournament index 1651
# Scraping tournament index 1652
# Scraping tournament index 1653
# Scraping tournament index 1654
# Scraping tournament index 1655
# Scraping tournament index 1656
# Scraping tournament index 1657
# Scraping tournament index 1658
# Scraping tournament index 1659
# Scraping tournament index 1660
# Scraping tournament index 1661
# Scraping tournament index 1662
# Scraping tournament index 1663
# Scraping tournament index 1664
# Scraping tournament index 1665
# Scraping tournament index 1666
# Scraping tournament index 1667
# Scraping tournament index 1668
# Scraping tournament index 1669
# Scraping tournament index 1670
# Scraping tournament index 1671
# Scraping tournament index 1672
# Scraping tournament index 1673
# Scraping tournament index 1674
# Scraping tournament index 1675
# Scraping tournament index 1676
# Scraping tournament index 1677
# Scraping tournament index 1678
# Scraping tournament index 1679
# Scraping tournament index 1680
# Scraping tournament index 1681
# Scraping tournament index 1682
# Scraping tournament index 1683
# Scraping tournament index 1684
# Scraping tournament index 1685
# Scraping tournament index 1686
# Scraping tournament index 1687
# Scraping tournament index 1688
# Scraping tournament index 1689
# Scraping tournament index 1690
# Scraping tournament index 1691
# Scraping tournament index 1692
# Scraping tournament index 1693
# Scraping tournament index 1694
# Scraping tournament index 1695
# Scraping tournament index 1696
# Scraping tournament index 1697
# Scraping tournament index 1698
# Scraping tournament index 1699
# Scraping tournament index 1700
# Scraping tournament index 1701
# Scraping tournament index 1702
# Scraping tournament index 1703
# Scraping tournament index 1704
# Scraping tournament index 1705
# Scraping tournament index 1706
# Scraping tournament index 1707
# Scraping tournament index 1708
# Scraping tournament index 1709
# Scraping tournament index 1710
# Scraping tournament index 1711
# Scraping tournament index 1712
# Scraping tournament index 1713
# Scraping tournament index 1714
# Scraping tournament index 1715
# Scraping tournament index 1716
# Scraping tournament index 1717
# Scraping tournament index 1718
# Scraping tournament index 1719
# Scraping tournament index 1720
# Scraping tournament index 1721
# Scraping tournament index 1722
# Scraping tournament index 1723
# Scraping tournament index 1724
# Scraping tournament index 1725
# Scraping tournament index 1726
# Scraping tournament index 1727
# Scraping tournament index 1728
# Scraping tournament index 1729
# Scraping tournament index 1730
# Scraping tournament index 1731
# Scraping tournament index 1732
# Scraping tournament index 1733
# Scraping tournament index 1734
# Scraping tournament index 1735
# Scraping tournament index 1736
# Scraping tournament index 1737
# Scraping tournament index 1738
# Scraping tournament index 1739
# Scraping tournament index 1740
# Scraping tournament index 1741
# Scraping tournament index 1742
# Scraping tournament index 1743
# Scraping tournament index 1744
# Scraping tournament index 1745
# Scraping tournament index 1746
# Scraping tournament index 1747
# Scraping tournament index 1748
# Scraping tournament index 1749
# Scraping tournament index 1750
# Scraping tournament index 1751
# Scraping tournament index 1752
# Scraping tournament index 1753
# Scraping tournament index 1754
# Scraping tournament index 1755
# Scraping tournament index 1756
# Scraping tournament index 1757
# Scraping tournament index 1758
# Scraping tournament index 1759
# Scraping tournament index 1760
# Scraping tournament index 1761
# Scraping tournament index 1762
# Scraping tournament index 1763
# Scraping tournament index 1764
# Scraping tournament index 1765
# Scraping tournament index 1766
# Scraping tournament index 1767
# Scraping tournament index 1768
# Scraping tournament index 1769
# Scraping tournament index 1770
# Scraping tournament index 1771
# Scraping tournament index 1772
# Scraping tournament index 1773
# Scraping tournament index 1774
# Scraping tournament index 1775
# Scraping tournament index 1776
# Scraping tournament index 1777
# Scraping tournament index 1778
# Scraping tournament index 1779
# Scraping tournament index 1780
# Scraping tournament index 1781
# Scraping tournament index 1782
# Scraping tournament index 1783
# Scraping tournament index 1784
# Scraping tournament index 1785
# Scraping tournament index 1786
# Scraping tournament index 1787
# Scraping tournament index 1788
# Scraping tournament index 1789
# Scraping tournament index 1790
# Scraping tournament index 1791
# Scraping tournament index 1792
# Scraping tournament index 1793
# Scraping tournament index 1794
# Scraping tournament index 1795
# Scraping tournament index 1796
# Scraping tournament index 1797
# Scraping tournament index 1798
# Scraping tournament index 1799
# Scraping tournament index 1800
# Scraping tournament index 1801
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1802
# Scraping tournament index 1803
# Scraping tournament index 1804
# Scraping tournament index 1805
# Scraping tournament index 1806
# Scraping tournament index 1807
# Scraping tournament index 1808
# Scraping tournament index 1809
# Scraping tournament index 1810
# Scraping tournament index 1811
# Scraping tournament index 1812
# Scraping tournament index 1813
# Scraping tournament index 1814
# Scraping tournament index 1815
# Scraping tournament index 1816
# Scraping tournament index 1817
# Scraping tournament index 1818
# Scraping tournament index 1819
# Scraping tournament index 1820
# Scraping tournament index 1821
# Scraping tournament index 1822
# Scraping tournament index 1823
# Scraping tournament index 1824
# Scraping tournament index 1825
# Scraping tournament index 1826
# Scraping tournament index 1827
# Scraping tournament index 1828
# Scraping tournament index 1829
# Scraping tournament index 1830
# Scraping tournament index 1831
# Scraping tournament index 1832
# Scraping tournament index 1833
# Scraping tournament index 1834
# Scraping tournament index 1835
# Scraping tournament index 1836
# Scraping tournament index 1837
# Scraping tournament index 1838
# Scraping tournament index 1839
# Scraping tournament index 1840
# Scraping tournament index 1841
# Scraping tournament index 1842
# Scraping tournament index 1843
# Scraping tournament index 1844
# Scraping tournament index 1845
# Scraping tournament index 1846
# Scraping tournament index 1847
# Scraping tournament index 1848
# Scraping tournament index 1849
# Scraping tournament index 1850
# Scraping tournament index 1851
# Scraping tournament index 1852
# Scraping tournament index 1853
# Scraping tournament index 1854
# Scraping tournament index 1855
# Scraping tournament index 1856
# Scraping tournament index 1857
# Scraping tournament index 1858
# Scraping tournament index 1859
# Scraping tournament index 1860
# Scraping tournament index 1861
# Scraping tournament index 1862
# Scraping tournament index 1863
# Scraping tournament index 1864
# Scraping tournament index 1865
# Scraping tournament index 1866
# Scraping tournament index 1867
# Scraping tournament index 1868
# Scraping tournament index 1869
# Scraping tournament index 1870
# Scraping tournament index 1871
# Scraping tournament index 1872
# Scraping tournament index 1873
# Scraping tournament index 1874
# Scraping tournament index 1875
# Scraping tournament index 1876
# Scraping tournament index 1877
# Scraping tournament index 1878
# Scraping tournament index 1879
# Scraping tournament index 1880
# Scraping tournament index 1881
# Scraping tournament index 1882
# Scraping tournament index 1883
# Scraping tournament index 1884
# Scraping tournament index 1885
# Scraping tournament index 1886
# Scraping tournament index 1887
# Scraping tournament index 1888
# Scraping tournament index 1889
# Scraping tournament index 1890
# Scraping tournament index 1891
# Scraping tournament index 1892
# Scraping tournament index 1893
# Scraping tournament index 1894
# Scraping tournament index 1895
# Scraping tournament index 1896
# Scraping tournament index 1897
# Scraping tournament index 1898
# Scraping tournament index 1899
# Scraping tournament index 1900
# Scraping tournament index 1901
# Scraping tournament index 1902
# Scraping tournament index 1903
# Scraping tournament index 1904
# Scraping tournament index 1905
# Scraping tournament index 1906
# Scraping tournament index 1907
# Scraping tournament index 1908
# Scraping tournament index 1909
# Scraping tournament index 1910
# Scraping tournament index 1911
# Scraping tournament index 1912
# Scraping tournament index 1913
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1914
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1915
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1916
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1917
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1918
# Scraping tournament index 1919
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1920
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1921
# Scraping tournament index 1922
# Scraping tournament index 1923
# Scraping tournament index 1924
# Scraping tournament index 1925
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1926
# Scraping tournament index 1927
# Scraping tournament index 1928
# Scraping tournament index 1929
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1930
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1931
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1932
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1933
# Scraping tournament index 1934
# Scraping tournament index 1935
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1936
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1937
# Scraping tournament index 1938
# Scraping tournament index 1939
# Scraping tournament index 1940
# Scraping tournament index 1941
# Scraping tournament index 1942
# Scraping tournament index 1943
# Scraping tournament index 1944
# Scraping tournament index 1945
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1946
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1947
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1948
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1949
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1950
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1951
# Error in scraping with missing javascript variable, skipping.
# Scraping tournament index 1952
# Error in scraping with missing javascript variable, skipping.
# Wall time: 1h 14min 19s

# %%
# Passing to dataframe
matches_df = pd.DataFrame(matches)
matches_df
# Out:
#                                      tournament  \
# 0               epicgames_S19_PlaystationCup_EU
# 1               epicgames_S19_PlaystationCup_EU
# 2               epicgames_S19_PlaystationCup_EU
# 3               epicgames_S19_PlaystationCup_EU
# 4               epicgames_S19_PlaystationCup_EU
# ...                                         ...
# 15748  epicgames_ShareTheLove_Prospect_Solo_OCE
# 15749  epicgames_ShareTheLove_Prospect_Solo_OCE
# 15750  epicgames_ShareTheLove_Prospect_Solo_OCE
# 15751  epicgames_ShareTheLove_Prospect_Solo_OCE
# 15752  epicgames_ShareTheLove_Prospect_Solo_OCE
#
#                                  event_round                          match_id
# 0        S19_PlaystationCup_EU_Event1_Round2  2f5edf4cf77e4d62a1a596097527fc7c
# 1        S19_PlaystationCup_EU_Event1_Round2  cda0a24adfed404e884236740bacc1f7
# 2        S19_PlaystationCup_EU_Event1_Round2  011af1ad879c45e0ad8607647220efe0
# 3        S19_PlaystationCup_EU_Event1_Round2  c0d7f093a3ba48e0960c2c2c74014b75
# 4        S19_PlaystationCup_EU_Event1_Round2  001e52411f634f7a938c76c0681482cd
# ...                                      ...                               ...
# 15748  ShareTheLove_Prospect_Solo_OCE_Event5  0b0964ff5a0d4271aeb8ad9174924202
# 15749  ShareTheLove_Prospect_Solo_OCE_Event5  371895f9332948e6970a748461a92cdf
# 15750  ShareTheLove_Prospect_Solo_OCE_Event5  1e2590adc4d743028839efdfbd5c3ed6
# 15751  ShareTheLove_Prospect_Solo_OCE_Event5  0f1d50843a304eda8e51ae6857cde1ac
# 15752  ShareTheLove_Prospect_Solo_OCE_Event5  769eda8f1ca4466fb1167de5f5ba7183
#
# [15753 rows x 3 columns]

# %%
# Saving to file
matches_df.to_csv('../datasets/match_ids.csv', index = False)

# %% [markdown]
# <a id='progress'></a>
# ### 3. Progress so far
# In [Part 1-1 Webscraping Match IDs](./1-1.webscraping_match_ids.ipynb), we have finished the web scraping of the match ids from the website `Fortnite Tracker` that are going to be used for the web scraping of the match sessions which will contain all of the match statistics for our analysis.
#
# It should be noted that the match ids that had been scraped are not comprehensive since there are various issues with the website that made webscraping difficult. This is not considered as a heavy issue since there are enough matches sessions for analysis.
#
# We will continue next in: [Part 1-2 Webscraping Match Sessions](./1-2.webscraping_match_sessions.ipynb)
